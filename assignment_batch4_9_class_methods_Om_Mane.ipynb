# %% [markdown]
# ## Q1: Create a class called Student
#
# Requirements:
# - Class variable: `school_name = "ABC International School"`
# - Constructor: takes `name` and `marks`
# - Instance method: `display_details()`
# - Class method: `change_school()`
# - Static method: `is_pass(marks)` returns "Pass" if marks ≥ 35 else "Fail"

# %%
class Student :
    school_name="ABC Internationl School"

    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
      
    def display_details(self):
        print('name:',self.name)
        print( 'marks:', self.marks)
        print('school name:',Student.school_name)
        print('result:',Student.is_pass(self.marks))
    @classmethod
    def change_school(cls, new_name):
        cls.school_name= new_name

    def is_pass(marks):
        if marks >=35:
            return "pass"
        else:
            return "fail"


S=Student('om',90)
S.display_details()

Student.change_school('adarsh balak')
# Out:
# name: om
# marks: 90
# school name: ABC Internationl School
# result: pass

# %% [markdown]
# ## Q2: Create a class Calculator
#
# Requirements:
# - Class variable: `count_operations = 0`
# - Instance method: `add(a, b)`
# - Class method: `increment_count()`
# - Static method: `info()`

# %%
class calculater:
    count_operations=0

    def add(self,a,b):
     result = a+b
     calculater.increament_count()
     return result
    @classmethod
    def increament_count(cls):
    
        cls.count_operations+=1

    def info():
        print("simple addition opert=ation")

C=calculater()
C.add(2,5)

print("Total operations:", calculater.count_operations)
calculater.info()
# Out:
# Total operations: 1
# simple addition opert=ation

# %% [markdown]
# ## Q3: Write a class BankAccount
#
# Requirements:
# - Class variable: `bank_name = "SBI"`
# - Constructor: `name`, `balance`
# - Instance method: `deposit(amount)`
# - Class method: `change_bank(new_name)`
# - Static method: `validate_amount(amount)`

# %%
class BankAccount:
    bank_name="SBI"

    def __init__(self,name,balance):
        self.name=name
        self.balance=balance
    def deposit(self,amount):
        if BankAccount.validate_amount(amount):
            self.balance += amount
            print(f"Deposited {amount}. New balance: {self.balance}")
        else:
            print("Invalid amount!")
    @classmethod
    def change_bank(cls,new_name):
        cls.bank_name=new_name
    def validate_amount(amount):
        return amount>0

acc = BankAccount("Om", 1000)
acc.deposit(500)

BankAccount.change_bank("HDFC")

print("Bank Name:", BankAccount.bank_name)
# Out:
# Deposited 500. New balance: 1500
# Bank Name: HDFC
